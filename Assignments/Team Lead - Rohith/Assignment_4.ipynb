# %% [markdown]
# # Importing the Libraries
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# # Reading Dataset & Pre-Preocessing
# ---

# %%
df = pd.read_csv('/content/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %% [markdown]
# ## Processing Data
# ---

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  43,  35,  68],
#        [  0,   0,   0, ...,   8, 981,  27],
#        [  0,   0,   0, ..., 501,  15,  39],
#        ...,
#        [  0,   0,   0, ..., 811, 205, 568],
#        [  0,   0,   0, ...,  23, 230, 402],
#        [  0,   0,   0, ...,   5, 240, 142]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'not',
#  25: 'but',
#  26: 'do',
#  27: 'or',
#  28: 'can',
#  29: "i'm",
#  30: 'at',
#  31: 'get',
#  32: 'with',
#  33: 'be',
#  34: 'ur',
#  35: 'no',
#  36: 'will',
#  37: 'if',
#  38: 'just',
#  39: 'this',
#  40: 'we',
#  41: 'gt',
#  42: 'lt',
#  43: '4',
#  44: 'up',
#  45: 'free',
#  46: 'go',
#  47: 'ok',
#  48: 'when',
#  49: 'from',
#  50: 'how',
#  51: 'out',
#  52: 'all',
#  53: 'what',
#  54: 'know',
#  55: 'good',
#  56: 'got',
#  57: 'like',
#  58: 'then',
#  59: 'come',
#  60: 'its',
#  61: 'was',
#  62: 'time',
#  63: 'only',
#  64: 'am',
#  65: 'love',
#  66: 'day',
#  67: 'there',
#  68: 'send',
#  69: 'he',
#  70: 'want',
#  71: 'text',
#  72: 'as',
#  73: 'need',
#  74: 'going',
#  75: 'one',
#  76: 'by',
#  77: 'txt',
#  78: 'about',
#  79: 'sorry',
#  80: 'lor',
#  81: 'home',
#  82: "i'll",
#  83: 'stop',
#  84: 'n',
#  85: 'still',
#  86: 'r',
#  87: 'back',
#  88: 'see',
#  89: 'mobile',
#  90: 'today',
#  91: 'reply',
#  92: 'our',
#  93: 'k',
#  94: 'please',
#  95: 'dont',
#  96: 'she',
#  97: 'pls',
#  98: 'her',
#  99: 'think',
#  100: 'take',
#  101: 'tell',
#  102: "don't",
#  103: 'new',
#  104: 'da',
#  105: 'any',
#  106: 'been',
#  107: 'later',
#  108: 'hi',
#  109: 'some',
#  110: 'phone',
#  111: 'week',
#  112: 'here',
#  113: 'night',
#  114: 'great',
#  115: 'did',
#  116: 'much',
#  117: 'they',
#  118: 'has',
#  119: '1',
#  120: 'dear',
#  121: 'ì',
#  122: 'an',
#  123: 'hey',
#  124: 'claim',
#  125: 'hope',
#  126: 'oh',
#  127: 'well',
#  128: 'had',
#  129: 'msg',
#  130: 'him',
#  131: 'yes',
#  132: 'who',
#  133: 'where',
#  134: 'too',
#  135: 'more',
#  136: 'message',
#  137: 'make',
#  138: 'e',
#  139: 'give',
#  140: 'work',
#  141: 'www',
#  142: 'way',
#  143: 'number',
#  144: 'wat',
#  145: 'c',
#  146: 'tomorrow',
#  147: "it's",
#  148: 'happy',
#  149: 'should',
#  150: 'after',
#  151: 'ask',
#  152: 'say',
#  153: 'd',
#  154: 'right',
#  155: 'cash',
#  156: 'already',
#  157: 'why',
#  158: 'doing',
#  159: 'meet',
#  160: 'yeah',
#  161: '3',
#  162: 'prize',
#  163: 'them',
#  164: 'find',
#  165: 'life',
#  166: 'im',
#  167: 'said',
#  168: 'amp',
#  169: 'really',
#  170: 'morning',
#  171: 'babe',
#  172: 'would',
#  173: 'last',
#  174: 'cos',
#  175: 'thanks',
#  176: 't',
#  177: 'let',
#  178: 'also',
#  179: 'anything',
#  180: 'b',
#  181: 'sent',
#  182: 'win',
#  183: 'sure',
#  184: 'com',
#  185: 'every',
#  186: 'urgent',
#  187: 'pick',
#  188: 'cant',
#  189: 'lol',
#  190: 'us',
#  191: 'very',
#  192: 'wait',
#  193: 'nokia',
#  194: "i've",
#  195: 'soon',
#  196: 'something',
#  197: '150p',
#  198: 'min',
#  199: 'miss',
#  200: 'uk',
#  201: 'care',
#  202: 'contact',
#  203: 'won',
#  204: 'keep',
#  205: 'before',
#  206: 'again',
#  207: 'feel',
#  208: 'place',
#  209: 'first',
#  210: 'buy',
#  211: 'many',
#  212: 'over',
#  213: 'went',
#  214: 's',
#  215: "can't",
#  216: 'were',
#  217: 'sms',
#  218: 'his',
#  219: 'per',
#  220: 'next',
#  221: 'leave',
#  222: 'even',
#  223: 'customer',
#  224: 'off',
#  225: 'could',
#  226: '5',
#  227: 'money',
#  228: 'tonight',
#  229: 'tone',
#  230: 'nice',
#  231: 'chat',
#  232: 'gonna',
#  233: 'someone',
#  234: 'sleep',
#  235: 'always',
#  236: 'wan',
#  237: 'co',
#  238: 'around',
#  239: 'service',
#  240: 'other',
#  241: 'gud',
#  242: 'dun',
#  243: 'things',
#  244: 'thing',
#  245: 'help',
#  246: 'x',
#  247: 'down',
#  248: '50',
#  249: 'wish',
#  250: 'late',
#  251: 'told',
#  252: 'people',
#  253: 'ya',
#  254: "you're",
#  255: 'done',
#  256: 'ìï',
#  257: 'hello',
#  258: 'which',
#  259: '16',
#  260: "that's",
#  261: 'thk',
#  262: '18',
#  263: 'waiting',
#  264: 'friends',
#  265: 'fine',
#  266: 'yet',
#  267: 'getting',
#  268: 'haha',
#  269: '7',
#  270: 'heart',
#  271: 'live',
#  272: 'mins',
#  273: 'friend',
#  274: 'guaranteed',
#  275: 'holiday',
#  276: 'special',
#  277: 'use',
#  278: 'job',
#  279: 'better',
#  280: 'lunch',
#  281: 'may',
#  282: 'same',
#  283: 'name',
#  284: 'ill',
#  285: 'few',
#  286: 'year',
#  287: 'smile',
#  288: 'coming',
#  289: 'meeting',
#  290: 'house',
#  291: 'talk',
#  292: 'car',
#  293: 'man',
#  294: 'try',
#  295: 'being',
#  296: 'yup',
#  297: 'long',
#  298: 'bit',
#  299: 'stuff',
#  300: 'line',
#  301: 'never',
#  302: 'thought',
#  303: 'cs',
#  304: 'finish',
#  305: 'best',
#  306: "didn't",
#  307: 'v',
#  308: 'trying',
#  309: 'than',
#  310: 'camera',
#  311: '6',
#  312: 'y',
#  313: 'end',
#  314: 'thats',
#  315: 'ready',
#  316: 'class',
#  317: 'dat',
#  318: 'draw',
#  319: 'sir',
#  320: 'yo',
#  321: 'lar',
#  322: 'person',
#  323: 'latest',
#  324: 'chance',
#  325: 'because',
#  326: 'nothing',
#  327: 'check',
#  328: 'enjoy',
#  329: 'another',
#  330: 'jus',
#  331: 'having',
#  332: 'cool',
#  333: 'account',
#  334: 'problem',
#  335: 'days',
#  336: 'month',
#  337: 'liao',
#  338: 'word',
#  339: 'awarded',
#  340: 'receive',
#  341: 'wanna',
#  342: 'ah',
#  343: 'guys',
#  344: 'play',
#  345: 'offer',
#  346: 'sweet',
#  347: 'watching',
#  348: 'tv',
#  349: 'quite',
#  350: 'lot',
#  351: 'speak',
#  352: 'world',
#  353: 'god',
#  354: 'mind',
#  355: 'guess',
#  356: 'might',
#  357: 'wk',
#  358: 'ever',
#  359: '150ppm',
#  360: 'start',
#  361: 'shows',
#  362: 'cost',
#  363: 'apply',
#  364: 'landline',
#  365: 'å£1',
#  366: 'eat',
#  367: 'big',
#  368: 'into',
#  369: 'luv',
#  370: 'real',
#  371: 'xxx',
#  372: 'video',
#  373: 'birthday',
#  374: 'half',
#  375: 'called',
#  376: 'dinner',
#  377: 'little',
#  378: 'plan',
#  379: 'orange',
#  380: 'å£1000',
#  381: 'den',
#  382: 'baby',
#  383: 'does',
#  384: 'bad',
#  385: 'pa',
#  386: 'actually',
#  387: 'bt',
#  388: 'rate',
#  389: 'box',
#  390: 'shit',
#  391: 'maybe',
#  392: 'room',
#  393: 'texts',
#  394: 'pay',
#  395: 'hear',
#  396: 'face',
#  397: 'girl',
#  398: 'aight',
#  399: 'shopping',
#  400: 'award',
#  401: 'dunno',
#  402: 'leh',
#  403: 'watch',
#  404: 'remember',
#  405: 'kiss',
#  406: 'everything',
#  407: 'ringtone',
#  408: '1st',
#  409: 'forgot',
#  410: 'll',
#  411: 'boy',
#  412: 'mail',
#  413: 'part',
#  414: 'code',
#  415: 'evening',
#  416: 'shall',
#  417: 'left',
#  418: '8',
#  419: '9',
#  420: 'says',
#  421: '10',
#  422: 'wife',
#  423: 'fun',
#  424: 'po',
#  425: 'bus',
#  426: 'update',
#  427: 'dis',
#  428: 'most',
#  429: 'between',
#  430: 'network',
#  431: 'selected',
#  432: 'princess',
#  433: 'times',
#  434: 'missing',
#  435: 'weekend',
#  436: 'town',
#  437: 'wont',
#  438: '2nd',
#  439: 'easy',
#  440: 'anyway',
#  441: 'once',
#  442: 'early',
#  443: 'sat',
#  444: 'm',
#  445: 'working',
#  446: 'looking',
#  447: "he's",
#  448: 'thank',
#  449: '000',
#  450: 'while',
#  451: 'office',
#  452: 'wif',
#  453: 'xmas',
#  454: 'two',
#  455: 'look',
#  456: 'probably',
#  457: 'thanx',
#  458: 'collection',
#  459: 'tmr',
#  460: 'sexy',
#  461: 'minutes',
#  462: 'means',
#  463: 'details',
#  464: 'de',
#  465: "there's",
#  466: 'bed',
#  467: 'enough',
#  468: 'afternoon',
#  469: 'messages',
#  470: 'able',
#  471: 'hour',
#  472: 'must',
#  473: 'bring',
#  474: '10p',
#  475: 'came',
#  476: 'school',
#  477: 'missed',
#  478: 'put',
#  479: 'dad',
#  480: 'made',
#  481: 'calls',
#  482: 'wot',
#  483: 'reach',
#  484: 'join',
#  485: 'plus',
#  486: 'g',
#  487: 'hair',
#  488: 'entry',
#  489: 'makes',
#  490: 'shop',
#  491: 'online',
#  492: 'pain',
#  493: 'fuck',
#  494: "how's",
#  495: 'tones',
#  496: 'wake',
#  497: 'goin',
#  498: 'abt',
#  499: 'havent',
#  500: 'http',
#  501: 'bored',
#  502: 'valid',
#  503: 'food',
#  504: 'without',
#  505: 'dude',
#  506: 'saw',
#  507: 'those',
#  508: 'hav',
#  509: 'until',
#  510: 'important',
#  511: 'asked',
#  512: 'national',
#  513: 'till',
#  514: 'price',
#  515: 'wanted',
#  516: 'sae',
#  517: 'ard',
#  518: 'else',
#  519: 'didnt',
#  520: 'collect',
#  521: 'test',
#  522: 'oso',
#  523: 'attempt',
#  524: 'years',
#  525: 'juz',
#  526: 'haf',
#  527: 'id',
#  528: 'sad',
#  529: 'alright',
#  530: 'decimal',
#  531: 'tried',
#  532: 'chikku',
#  533: 'weekly',
#  534: 'music',
#  535: 'change',
#  536: 'mob',
#  537: 'show',
#  538: 'since',
#  539: 'lei',
#  540: 'driving',
#  541: 'true',
#  542: 'await',
#  543: 'yourself',
#  544: 'goes',
#  545: 'colour',
#  546: 'words',
#  547: 'order',
#  548: 'family',
#  549: 'friendship',
#  550: 'okay',
#  551: 'answer',
#  552: 'okie',
#  553: 're',
#  554: 'net',
#  555: 'yours',
#  556: 'either',
#  557: 'feeling',
#  558: 'drive',
#  559: 'double',
#  560: 'question',
#  561: 'movie',
#  562: 'news',
#  563: 'delivery',
#  564: "we're",
#  565: 'ring',
#  566: 'these',
#  567: 'å£5000',
#  568: 'though',
#  569: 'book',
#  570: 'away',
#  571: 'busy',
#  572: 'calling',
#  573: 'wid',
#  574: 'hot',
#  575: 'took',
#  576: 'charge',
#  577: 'run',
#  578: 'gift',
#  579: 'top',
#  580: 'worry',
#  581: 'coz',
#  582: "won't",
#  583: 'tot',
#  584: 'guy',
#  585: 'noe',
#  586: 'rite',
#  587: 'comes',
#  588: 'email',
#  589: '500',
#  590: 'plz',
#  591: 'stay',
#  592: 'yesterday',
#  593: 'nite',
#  594: 'date',
#  595: 'w',
#  596: 'row',
#  597: 'hours',
#  598: 'address',
#  599: 'simple',
#  600: 'everyone',
#  601: 'lucky',
#  602: 'both',
#  603: 'forget',
#  604: 'drink',
#  605: 'services',
#  606: 'huh',
#  607: 'started',
#  608: 'mean',
#  609: 'games',
#  610: '750',
#  611: 'vouchers',
#  612: 'å£100',
#  613: 'trip',
#  614: "what's",
#  615: 'points',
#  616: 'walk',
#  617: 'finished',
#  618: 'drop',
#  619: 'lets',
#  620: 'set',
#  621: 'old',
#  622: 'saying',
#  623: 'todays',
#  624: 'minute',
#  625: 'wants',
#  626: 'bonus',
#  627: 'til',
#  628: 'cause',
#  629: 'dreams',
#  630: 'hurt',
#  631: 'gr8',
#  632: 'head',
#  633: 'story',
#  634: 'auction',
#  635: 'making',
#  636: 'pub',
#  637: 'wen',
#  638: 'full',
#  639: 'eve',
#  640: 'pounds',
#  641: 'sleeping',
#  642: 'post',
#  643: 'treat',
#  644: 'tomo',
#  645: "we'll",
#  646: '8007',
#  647: 'poly',
#  648: 'tho',
#  649: 'brother',
#  650: 'private',
#  651: 'beautiful',
#  652: 'å£2000',
#  653: 'pm',
#  654: 'together',
#  655: 'lose',
#  656: 'opt',
#  657: 'ha',
#  658: 'xx',
#  659: "c's",
#  660: 'pic',
#  661: 'sister',
#  662: 'aft',
#  663: "''",
#  664: 'touch',
#  665: 'close',
#  666: 'awesome',
#  667: 'sis',
#  668: 'smth',
#  669: 'darlin',
#  670: 'available',
#  671: 'hard',
#  672: 'found',
#  673: 'unsubscribe',
#  674: 'smoke',
#  675: 'kind',
#  676: 'needs',
#  677: 'taking',
#  678: 'frnd',
#  679: 'pics',
#  680: 'expires',
#  681: 'thinking',
#  682: 'neva',
#  683: 'sea',
#  684: 'worth',
#  685: '08000930705',
#  686: '11',
#  687: 'believe',
#  688: 'leaving',
#  689: 'each',
#  690: 'land',
#  691: '12hrs',
#  692: '86688',
#  693: 'happen',
#  694: "haven't",
#  695: 'card',
#  696: 'prob',
#  697: 'game',
#  698: 'chennai',
#  699: 'whatever',
#  700: 'sun',
#  701: 'happened',
#  702: 'saturday',
#  703: 'mine',
#  704: 'wil',
#  705: 'girls',
#  706: 'congrats',
#  707: 'suite342',
#  708: '2lands',
#  709: 'winner',
#  710: 'gd',
#  711: 'alone',
#  712: 'sch',
#  713: 'parents',
#  714: '100',
#  715: "you'll",
#  716: 'outside',
#  717: 'log',
#  718: 'lots',
#  719: 'carlos',
#  720: 'å£500',
#  721: 'finally',
#  722: 'anyone',
#  723: 'statement',
#  724: 'identifier',
#  725: '\x89û',
#  726: 'dating',
#  727: 'operator',
#  728: 'savamob',
#  729: 'anytime',
#  730: 'loving',
#  731: 'smiling',
#  732: 'friday',
#  733: 'wrong',
#  734: 'visit',
#  735: 'second',
#  736: 'goodmorning',
#  737: 'choose',
#  738: 'break',
#  739: 'far',
#  740: 'club',
#  741: 'unlimited',
#  742: 'camcorder',
#  743: 'rs',
#  744: 'lovely',
#  745: 'final',
#  746: 'blue',
#  747: 'search',
#  748: 'knw',
#  749: 'secret',
#  750: 'park',
#  751: 'used',
#  752: 'understand',
#  753: 'takes',
#  754: 'open',
#  755: 'fri',
#  756: 'party',
#  757: 'hold',
#  758: 'freemsg',
#  759: 'ltd',
#  760: 'mobileupd8',
#  761: '08000839402',
#  762: 'enter',
#  763: 'mayb',
#  764: 'bout',
#  765: 'mate',
#  766: 'offers',
#  767: 'lesson',
#  768: 'area',
#  769: 'college',
#  770: 'gone',
#  771: 'msgs',
#  772: 'angry',
#  773: 'sounds',
#  774: 'ass',
#  775: 'pobox',
#  776: 'å£350',
#  777: 'light',
#  778: 'support',
#  779: 'mum',
#  780: 'don',
#  781: 'whats',
#  782: 'nt',
#  783: 'voucher',
#  784: 'crazy',
#  785: "you've",
#  786: 'boytoy',
#  787: 'ni8',
#  788: 'meant',
#  789: 'hmm',
#  790: 'sunday',
#  791: 'thinks',
#  792: 'difficult',
#  793: 'extra',
#  794: 'luck',
#  795: 'reason',
#  796: 'song',
#  797: 'frnds',
#  798: 'sex',
#  799: 'tc',
#  800: 'nope',
#  801: 'motorola',
#  802: 'credit',
#  803: 'fancy',
#  804: 'their',
#  805: 'earlier',
#  806: 'snow',
#  807: 'age',
#  808: 'mates',
#  809: 'project',
#  810: 'cum',
#  811: 'point',
#  812: 'swing',
#  813: 'ends',
#  814: 'type',
#  815: 'å£250',
#  816: 'telling',
#  817: 'pretty',
#  818: 'company',
#  819: 'mr',
#  820: 'å£2',
#  821: "she's",
#  822: 'currently',
#  823: 'fast',
#  824: 'decided',
#  825: 'mrng',
#  826: 'hungry',
#  827: 'christmas',
#  828: 'congratulations',
#  829: 'ac',
#  830: 'valued',
#  831: 'reveal',
#  832: 'hit',
#  833: 'seen',
#  834: 'o',
#  835: 'ugh',
#  836: 'content',
#  837: 'å£3',
#  838: 'dnt',
#  839: 'india',
#  840: 'bank',
#  841: 'kate',
#  842: 'least',
#  843: '20',
#  844: 'uncle',
#  845: 'information',
#  846: 'picking',
#  847: 'fucking',
#  848: 'quiz',
#  849: 'mu',
#  850: '87066',
#  851: '30',
#  852: 'own',
#  853: 'confirm',
#  854: '800',
#  855: 'fr',
#  856: 'b4',
#  857: 'gotta',
#  858: 'yar',
#  859: 'etc',
#  860: "i'd",
#  861: 'darren',
#  862: 'march',
#  863: 'via',
#  864: 'within',
#  865: 'felt',
#  866: 'lost',
#  867: 'gym',
#  868: 'frm',
#  869: 'read',
#  870: 'almost',
#  871: 'mobiles',
#  872: 'happiness',
#  873: 'listen',
#  874: 'gas',
#  875: 'hows',
#  876: 'comp',
#  877: 'ipod',
#  878: 'caller',
#  879: '03',
#  880: 'weeks',
#  881: 'balance',
#  882: "doesn't",
#  883: 'semester',
#  884: 'fone',
#  885: 'heard',
#  886: 'charged',
#  887: 'knew',
#  888: 'through',
#  889: 'seeing',
#  890: 'direct',
#  891: 'mom',
#  892: 'ten',
#  893: 'hand',
#  894: 'wit',
#  895: 'player',
#  896: 'wonderful',
#  897: 'drugs',
#  898: 'hg',
#  899: 'w1j6hl',
#  900: 'reward',
#  901: 'move',
#  902: 'doin',
#  903: 'crave',
#  904: 'questions',
#  905: 'couple',
#  906: 'hmmm',
#  907: 'lovable',
#  908: 'tel',
#  909: 'hee',
#  910: 'convey',
#  911: 'poor',
#  912: 'ex',
#  913: 'kids',
#  914: 'grins',
#  915: 'info',
#  916: 'checking',
#  917: 'fantastic',
#  918: 'surprise',
#  919: 'police',
#  920: 'hoping',
#  921: 'bathe',
#  922: 'asking',
#  923: 'course',
#  924: 'welcome',
#  925: 'nyt',
#  926: 'store',
#  927: 'monday',
#  928: 'sell',
#  929: 'call2optout',
#  930: 'f',
#  931: '2003',
#  932: 'un',
#  933: 'redeemed',
#  934: '04',
#  935: 'computer',
#  936: 'talking',
#  937: 'discount',
#  938: 'sub',
#  939: 'rental',
#  940: 'father',
#  941: 'john',
#  942: 'txts',
#  943: 'pete',
#  944: 'del',
#  945: 'eg',
#  946: 'mah',
#  947: 'dream',
#  948: 'whenever',
#  949: 'yr',
#  950: 'terms',
#  951: 'phones',
#  952: 'match',
#  953: 'red',
#  954: 'blood',
#  955: 'asap',
#  956: 'somewhere',
#  957: 'plans',
#  958: "isn't",
#  959: 'less',
#  960: 'otherwise',
#  961: 'sound',
#  962: 'wkly',
#  963: 'ts',
#  964: 'glad',
#  965: 'reading',
#  966: 'invited',
#  967: 'link',
#  968: 'std',
#  969: 'rest',
#  970: 'cut',
#  971: 'abiola',
#  972: 'whole',
#  973: 'across',
#  974: 'rock',
#  975: 'oredi',
#  976: 'orchard',
#  977: 'complimentary',
#  978: 'remove',
#  979: "'",
#  980: 'cheap',
#  981: 'tampa',
#  982: '12',
#  983: 'admirer',
#  984: 'trust',
#  985: 'mm',
#  986: 'lazy',
#  987: 'bcoz',
#  988: 'il',
#  989: 'nah',
#  990: 'film',
#  991: 'wow',
#  992: 'fact',
#  993: 'sick',
#  994: 'dead',
#  995: 'case',
#  996: 'immediately',
#  997: 'comuk',
#  998: 'rply',
#  999: 'na',
#  1000: 'å£10',
#  ...}

# %% [markdown]
# # Creating model and Adding Layers
# ---

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# # Compiling the model
# ---

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam",
metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262912
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 318,153
# Trainable params: 318,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fit the model
# ---

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
validation_split=0.2,

workers=10,
callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 15s 408ms/step - loss: 0.4801 - accuracy: 0.8471 - val_loss: 0.3203 - val_accuracy: 0.8703
# Epoch 2/10
# 30/30 [==============================] - 18s 616ms/step - loss: 0.2346 - accuracy: 0.9258 - val_loss: 0.0970 - val_accuracy: 0.9747

# %% [markdown]
# # Save the Model
# ---

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# # Test the Model
# ---

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1163 - accuracy: 0.9617

# %%
print('Test set\n Loss: {:0.3f}\n Accuracy:{:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#  Loss: 0.116
#  Accuracy:0.962
